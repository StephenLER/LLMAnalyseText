# %%
import pandas as pd

# %%
df = pd.read_pickle('/home/wangyuting/share/quant/wangyuting/liangjian/fac_data/logic_score2025_2025-09-30_final.pkl')

# %%
df.head()
# Out:
#   concept_code concept_name      next_trade_date      last_trade_date  \
# 0   8841639.WI      空气能热泵指数  2025-09-30 00:00:00  2025-09-29 00:00:00
# 1    884028.WI       智能电网指数  2025-09-30 00:00:00  2025-09-29 00:00:00
# 2    884188.WI       虚拟电厂指数  2025-09-30 00:00:00  2025-09-29 00:00:00
# 3    884790.WI         储能指数  2025-09-30 00:00:00  2025-09-29 00:00:00
# 4    884035.WI        新能源指数  2025-09-30 00:00:00  2025-09-29 00:00:00
#
#                                           raw_result  \
# 0  好的，我现在需要处理用户关于空气能热泵概念在2025年9月30日的新闻影响评估。首先，用户提...
# 1  好的，我现在需要评估A股市场中智能电网概念在2025年9月30日当天的新闻对当日板块涨跌的影...
# 2  好的，我现在需要处理用户关于虚拟电厂概念在2025年9月30日的新闻影响评估。首先，我得仔细...
# 3  好的，我现在需要处理用户关于储能概念在2025年9月30日的评估请求。首先，我得仔细阅读所有...
# 4  好的，我现在需要处理用户关于A股新能源概念在2025年9月30日的评估请求。首先，我得仔细阅...
#
#                                               prompt  \
# 0  \n        你是一名量化研究团队中的金融分析助手，现在需要你对“A股市场中某个概念盘...
# 1  \n        你是一名量化研究团队中的金融分析助手，现在需要你对“A股市场中某个概念盘...
# 2  \n        你是一名量化研究团队中的金融分析助手，现在需要你对“A股市场中某个概念盘...
# ...

# %%
df['concept_code'].unique().tolist()
# Out:
# ['8841639.WI',
#  '884028.WI',
#  '884188.WI',
#  '884790.WI',
#  '884035.WI',
#  '884045.WI',
#  '884977.WI',
#  '8841338.WI',
#  '8841294.WI',
#  '8841272.WI',
#  '8841237.WI',
#  '884987.WI',
#  '8841321.WI',
#  '8841701.WI',
#  '884160.WI',
#  '8841901.WI',
#  '8841728.WI',
#  '8841729.WI',
#  '884953.WI',
#  '8841744.WI',
#  '8841683.WI',
#  '8841678.WI',
#  '884201.WI',
#  '8841669.WI',
#  '884766.WI',
#  '884061.WI',
#  '集成电路封测',
#  '8841660.WI',
#  '884036.WI',
#  '884780.WI',
#  '8841906.WI',
#  '机器人',
#  '884126.WI',
#  '8841699.WI',
#  '8841241.WI',
#  '其他电子Ⅱ',
#  '8841902.WI',
#  '光伏发电&风力发电',
#  '风电设备',
#  '884131.WI',
#  '8841889.WI',
#  '884091.WI',
#  '8841647.WI',
#  '8841690.WI',
#  '8841866.WI',
#  '8841049.WI',
#  '8841550.WI',
#  '8841702.WI',
#  '8841731.WI',
#  '8841064.WI',
#  '8841129.WI',
#  '8841644.WI',
#  '8841258.WI',
#  '8841756.WI',
#  '8841905.WI',
#  '8841896.WI',
#  '8841867.WI',
#  '884086.WI',
#  '8841911.WI',
#  '8841089.WI',
#  '黄金&白银',
# ...

# %%
df['concept_code'].nunique()
# Out:
# 374

# %%
df1 = pd.read_pickle('/home/wangyuting/share/quant/wangyuting/liangjian/量价资金数据_concept_new.pkl')

# %%
df1.columns
# Out:
# Index(['code', 'date', 'amt', 'close', 'high', 'low', 'open', 'volume',
#        '开盘净主动买入额', '尾盘净主动买入额', '主力净流入额', '开盘主力净流入额', '净主动买入额', '尾盘主力净流入额',
#        '开盘净主动买入额_成交额占比', '尾盘净主动买入额_成交额占比', '主力净流入额_成交额占比', '开盘主力净流入额_成交额占比',
#        '净主动买入额_成交额占比', '尾盘主力净流入额_成交额占比', 'dq_amtturnover', 'turn'],
#       dtype='object')

# %%
df1['code'].unique().tolist()
# Out:
# ['884001.WI',
#  '884025.WI',
#  '884027.WI',
#  '884028.WI',
#  '884030.WI',
#  '884031.WI',
#  '884032.WI',
#  '884034.WI',
#  '884035.WI',
#  '884036.WI',
#  '884037.WI',
#  '884039.WI',
#  '884040.WI',
#  '884041.WI',
#  '884043.WI',
#  '884045.WI',
#  '884046.WI',
#  '884047.WI',
#  '884048.WI',
#  '884050.WI',
#  '884052.WI',
#  '884053.WI',
#  '884057.WI',
#  '884059.WI',
#  '884061.WI',
#  '884062.WI',
#  '884068.WI',
#  '884069.WI',
#  '884073.WI',
#  '884074.WI',
#  '884075.WI',
#  '884076.WI',
#  '884077.WI',
#  '884079.WI',
#  '884080.WI',
#  '884081.WI',
#  '884086.WI',
#  '884087.WI',
#  '884088.WI',
#  '884089.WI',
#  '884090.WI',
#  '884091.WI',
#  '884092.WI',
#  '884093.WI',
#  '884095.WI',
#  '884096.WI',
#  '884097.WI',
#  '884098.WI',
#  '884099.WI',
#  '884100.WI',
#  '8841000.WI',
#  '8841001.WI',
#  '8841002.WI',
#  '8841004.WI',
#  '8841005.WI',
#  '8841006.WI',
#  '8841007.WI',
#  '884101.WI',
#  '8841011.WI',
#  '8841013.WI',
#  '8841014.WI',
# ...

# %%
df1[df1['code'] == '黑色家电']
# Out:
#         code       date           amt        close         high          low  \
# 151     黑色家电 2015-12-30           NaN  1000.000000  1000.000000  1000.000000
# 303     黑色家电 2015-12-31  2.154488e+09   981.910714  1001.912017   981.152679
# 455     黑色家电 2016-01-04  2.089659e+09   899.573271   984.817360   899.573271
# 607     黑色家电 2016-01-05  2.451750e+09   883.422690   904.021337   848.222088
# 759     黑色家电 2016-01-06  1.889520e+09   901.125693   902.890931   883.042519
# ...      ...        ...           ...          ...          ...          ...
# 366784  黑色家电 2025-11-17  2.428235e+09  1364.530965  1369.135821  1356.401599
# 366937  黑色家电 2025-11-18  2.887189e+09  1361.930045  1373.619330  1356.375092
# 367090  黑色家电 2025-11-19  2.205226e+09  1348.213722  1364.880830  1338.802571
# 367243  黑色家电 2025-11-20  1.861157e+09  1349.653562  1372.071791  1348.103689
# 367396  黑色家电 2025-11-21  2.804188e+09  1310.486972  1346.232843  1309.857148
#
# ...
